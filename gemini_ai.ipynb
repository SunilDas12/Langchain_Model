# %%
! pip install -q -U google-genai

# %%
import os

# %%
os.environ["GEMINI_API_KEY"]=" "

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# AI learns patterns from data to make intelligent decisions.

# %%
# multi-turn conversation (chat)

from google import genai

client=genai.Client()
chat=client.chats.create(model="gemini-2.5-flash")

response=chat.send_message("I have 2 dogs in my house")
print(response.text)

print("-"*50)

response=chat.send_message("How many paws are in  my house")
print(response.text)
# Out:
# That's wonderful! Two dogs means double the love and double the fun!
#
# What kind of dogs are they? Do they have names?
#
# Is there anything I can help you with regarding your dogs, or did you just want to share? I'm happy to chat about them!
# --------------------------------------------------
# That's an easy one! Assuming both of your dogs have all their paws:
#
# 2 dogs * 4 paws/dog = **8 paws** in your house!
