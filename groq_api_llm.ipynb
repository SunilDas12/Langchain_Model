# %%
! pip install -q -U groq

# %%
import os

# %%
os.environ["GROQ_API_KEY"]=" "

# %%
from groq import Groq

client=Groq()

chat_completion=client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content":"you are a helpful assistant"},
        {"role": "user", "content":"What is Deep learning"}
    ]
)
print(chat_completion.choices[0].message.content)
# Out:
# Deep Learning is a subset of Machine Learning (ML) that involves the use of neural networks with multiple layers to analyze and interpret data, particularly visual and speech data. It is a type of artificial intelligence (AI) that is inspired by the structure and function of the human brain.
#
# Deep Learning algorithms are designed to learn and represent complex patterns in data by automatically discovering and selecting the most relevant features. These algorithms are trained on large datasets, which enables them to learn and make predictions on their own, without the need for extensive programming.
#
# Key characteristics of Deep Learning:
#
# 1. **Neural networks**: Deep Learning algorithms are based on artificial neural networks, which are composed of layers of interconnected nodes (neurons) that process and transmit information.
# 2. **Multiple layers**: Neural networks typically have multiple layers, each of which processes different aspects of the input data.
# 3. **Autonomous feature extraction**: Deep Learning algorithms automatically extract relevant features from the data during training, without the need for manual feature engineering.
# 4. **Large datasets**: Deep Learning algorithms require large datasets to learn and make predictions.
# 5. **Training**: Deep Learning algorithms are trained using backpropagation, a variant of gradient descent.
#
# Types of Deep Learning:
#
# 1. **Supervised Learning**: The algorithm is trained on labeled data to learn a mapping between inputs and outputs.
# 2. **Unsupervised Learning**: The algorithm is trained on unlabeled data to identify patterns or structure in the data.
# 3. **Reinforcement Learning**: The algorithm learns through trial and error by interacting with an environment and receiving feedback.
#
# Applications of Deep Learning:
#
# 1. **Computer Vision**: Image recognition, object detection, image generation
# 2. **Natural Language Processing**: Text analysis, language translation, sentiment analysis
# 3. **Speech Recognition**: Speech-to-text systems
# 4. **Robotics**: Control and navigation of robots
# 5. **Predictive Maintenance**: Predicting equipment failures and maintenance needs
#
# Popular Deep Learning frameworks:
#
# 1. **TensorFlow**: An open-source framework developed by Google
# 2. **PyTorch**: An open-source framework developed by Facebook
# 3. **Keras**: A high-level framework that can run on top of TensorFlow or PyTorch
#
# In summary, Deep Learning is a powerful subset of Machine Learning that enables computers to analyze complex patterns in data and make predictions or decisions based on that analysis. Its applications are vast, and it has the potential to revolutionize many industries.
